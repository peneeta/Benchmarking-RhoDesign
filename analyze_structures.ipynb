# %% [markdown]
# # Structure Analysis
# Peneeta Wojcik

# %%
from structure_analysis import CalculateRMSDScore, CalculateTMScore

# %%
ref_2au4 = "aptamers/2AU4.pdb"
ref_5kpy = "aptamers/5KPY.pdb"
ref_6e8t = "aptamers/6E8T.pdb"

# %% [markdown]
# ## Check Low-Temp Structures

# %%
lowtemp_2au4_rd = "rhofold_pred/temp1e-5/2AU4_lowtemp_rhodesign/relaxed_1000_model.pdb"
lowtemp_5kpy_rd = "rhofold_pred/temp1e-5/5KPY_lowtemp_rhodesign/relaxed_1000_model.pdb"
lowtemp_6e8t_rd = "rhofold_pred/temp1e-5/6E8T_lowtemp_rhodesign/relaxed_1000_model.pdb"

# %%
rmsd = CalculateRMSDScore(ref_2au4, lowtemp_2au4_rd)
tm = CalculateTMScore(ref_2au4, lowtemp_2au4_rd)
print(rmsd)
print(tm)
# Out:
# 13.609345
# 0.039959468
# /Users/peneeta/Desktop/grad/courses/fall25/gen_ai_biomed/project/Benchmarking-RhoDesign/structure_analysis.py:84: UserWarning: Structures have different lengths: 41 vs 40. Using minimum length.
#   warnings.warn(f"Structures have different lengths: {len(coords1)} vs {len(coords2)}. Using minimum length.")
# /Users/peneeta/Desktop/grad/courses/fall25/gen_ai_biomed/project/Benchmarking-RhoDesign/structure_analysis.py:133: UserWarning: Structures have different lengths: 41 vs 40. Using minimum length.
#   warnings.warn(f"Structures have different lengths: {len(coords1)} vs {len(coords2)}. Using minimum length.")
